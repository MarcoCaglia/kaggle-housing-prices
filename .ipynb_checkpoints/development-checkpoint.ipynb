# %% [markdown]
# # Kaggle Competition: Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques
# ## Outline
# 1. Basic Exploration and EDA
# 2. Feature Engineering
# 5. Modelling
# 6. Submission

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utility import h1_correlation, rmsle
from scipy import stats
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures, RobustScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.metrics import r2_score
import xgboost as xgb
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv',index_col = 'Id')
df_test = pd.read_csv('test.csv',index_col = 'Id')
conserve_test_ids = df_train.shape[0]
df = pd.concat((df_train, df_test))
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Basic Exploration and EDA

# %%
# Show dataframe attributes
df.shape
# Out:
# (2919, 80)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2919 non-null int64
# BldgType         2919 non-null object
# BsmtCond         2837 non-null object
# BsmtExposure     2837 non-null object
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFinType1     2840 non-null object
# BsmtFinType2     2839 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2838 non-null object
# BsmtUnfSF        2918 non-null float64
# CentralAir       2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# Electrical       2918 non-null object
# EnclosedPorch    2919 non-null int64
# ExterCond        2919 non-null object
# ExterQual        2919 non-null object
# Exterior1st      2918 non-null object
# Exterior2nd      2918 non-null object
# Fence            571 non-null object
# FireplaceQu      1499 non-null object
# Fireplaces       2919 non-null int64
# Foundation       2919 non-null object
# FullBath         2919 non-null int64
# Functional       2917 non-null object
# GarageArea       2918 non-null float64
# GarageCars       2918 non-null float64
# GarageCond       2760 non-null object
# GarageFinish     2760 non-null object
# GarageQual       2760 non-null object
# GarageType       2762 non-null object
# GarageYrBlt      2760 non-null float64
# GrLivArea        2919 non-null int64
# HalfBath         2919 non-null int64
# Heating          2919 non-null object
# HeatingQC        2919 non-null object
# HouseStyle       2919 non-null object
# KitchenAbvGr     2919 non-null int64
# KitchenQual      2918 non-null object
# LandContour      2919 non-null object
# LandSlope        2919 non-null object
# LotArea          2919 non-null int64
# LotConfig        2919 non-null object
# LotFrontage      2433 non-null float64
# LotShape         2919 non-null object
# LowQualFinSF     2919 non-null int64
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# MasVnrArea       2896 non-null float64
# MasVnrType       2895 non-null object
# MiscFeature      105 non-null object
# MiscVal          2919 non-null int64
# MoSold           2919 non-null int64
# Neighborhood     2919 non-null object
# OpenPorchSF      2919 non-null int64
# OverallCond      2919 non-null int64
# OverallQual      2919 non-null int64
# PavedDrive       2919 non-null object
# PoolArea         2919 non-null int64
# PoolQC           10 non-null object
# RoofMatl         2919 non-null object
# RoofStyle        2919 non-null object
# SaleCondition    2919 non-null object
# SalePrice        1460 non-null float64
# SaleType         2918 non-null object
# ScreenPorch      2919 non-null int64
# Street           2919 non-null object
# TotRmsAbvGrd     2919 non-null int64
# TotalBsmtSF      2918 non-null float64
# Utilities        2917 non-null object
# WoodDeckSF       2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# YrSold           2919 non-null int64
# dtypes: float64(12), int64(25), object(43)
# memory usage: 1.8+ MB

# %%
# Examination of numerical variables (correlation to target)
num_features = [feature for feature in df.columns if df[feature].dtype!= 'object']

cols = 4
rows = 10

fig, ax = plt.subplots(rows,cols,figsize=(rows*3,cols*10))
i=0

for row in range(rows):
    for col in range(cols):
        if i<len(num_features):
            corr, p_val = h1_correlation(df,num_features[i],'SalePrice',permutations=1*10**1)
            sns.regplot(x=num_features[i],y='SalePrice',data=df,order=1,ax=ax[row][col]).set_title('Corr: {}\np-value: {}'.format(corr,p_val))
            i+=1
            
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\numpy\lib\function_base.py:2530: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-276-1e6fbcb61a78> in <module>
#      11     for col in range(cols):
#      12         if i<len(num_features):
# ---> 13             corr, p_val = h1_correlation(df,num_features[i],'SalePrice',permutations=1*10**1)
#      14             sns.regplot(x=num_features[i],y='SalePrice',data=df,order=1,ax=ax[row][col]).set_title('Corr: {}\np-value: {}'.format(corr,p_val))
#      15             i+=1
#
# ~\Documents\Repositories\kaggle_housing_prices\utility.py in h1_correlation(df, target, subject, permutations)
#      20     subject_array = np.array(testing_df[subject].dropna())
#      21
# ---> 22     base_correlation = np.corrcoef(target_array,subject_array)[0,1]
#      23     test_correlations = []
#      24
#
# ~\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2529     stddev = sqrt(d.real)
#    2530     c /= stddev[:, None]
# -> 2531     c /= stddev[None, :]
#    2532
#    2533     # Clip real and imaginary parts to [-1, 1].  This does not guarantee
#
# KeyboardInterrupt:

# %%
# Examination of non-numerical features (correlation matrix)

sns.heatmap(df.corr())

# %%
# Examination of numerical features (distributions)
cols = 4
rows = 10

fig, ax = plt.subplots(rows,cols,figsize=(rows*3,cols*10))
i=0

for row in range(rows):
    for col in range(cols):
        if i<len(num_features):
            sns.distplot(df[num_features[i]].dropna(),ax = ax[row][col]).set_title('p-value: {}'.format(stats.shapiro(df[num_features[i]].dropna())[1]))
            i+=1
            
plt.tight_layout()
plt.show()

# %%
# Examination of non-numerical features
non_numerical_features = [feature for feature in df.columns if feature not in num_features]

cols = 3
rows = 15

fig,ax = plt.subplots(rows,cols,figsize=(cols*5,rows*3))
i = 0

for row in range(rows):
    for col in range(cols):
        if i<len(non_numerical_features):
            cat_means = df.groupby(non_numerical_features[i])[[non_numerical_features[i],'SalePrice']].mean()
            target_cats = cat_means.index.tolist()
            target_means = list(cat_means.iloc[:,0])
            ordered_list = sorted(zip(target_means,target_cats),key=lambda x: x[0])
            order = np.array([y for x,y in ordered_list])
            sns.boxplot(x=non_numerical_features[i],y='SalePrice',data=df,order=order,ax=ax[row][col])
            i+=1
            
plt.tight_layout()

plt.show()

# %%
# Examination of missing data
missing_report = pd.DataFrame(df.isnull().sum().sort_values(ascending=False),columns=['missing_values'])
missing_report['missing_values_rel'] = missing_report['missing_values']/df.shape[0]
        
for index,value in missing_report.iterrows():
    if value[0]==0:
        missing_report.drop(index,inplace=True)
        
missing_report
# Out:
#               missing_values  missing_values_rel
# PoolQC                  2909            0.996574
# MiscFeature             2814            0.964029
# Alley                   2721            0.932169
# Fence                   2348            0.804385
# SalePrice               1459            0.499829
# FireplaceQu             1420            0.486468
# LotFrontage              486            0.166495
# GarageQual               159            0.054471
# GarageYrBlt              159            0.054471
# GarageFinish             159            0.054471
# GarageCond               159            0.054471
# GarageType               157            0.053786
# BsmtCond                  82            0.028092
# BsmtExposure              82            0.028092
# BsmtQual                  81            0.027749
# BsmtFinType2              80            0.027407
# BsmtFinType1              79            0.027064
# MasVnrType                24            0.008222
# MasVnrArea                23            0.007879
# MSZoning                   4            0.001370
# BsmtHalfBath               2            0.000685
# Utilities                  2            0.000685
# Functional                 2            0.000685
# BsmtFullBath               2            0.000685
# Electrical                 1            0.000343
# Exterior2nd                1            0.000343
# KitchenQual                1            0.000343
# GarageCars                 1            0.000343
# Exterior1st                1            0.000343
# GarageArea                 1            0.000343
# TotalBsmtSF                1            0.000343
# BsmtUnfSF                  1            0.000343
# BsmtFinSF2                 1            0.000343
# BsmtFinSF1                 1            0.000343
# SaleType                   1            0.000343

# %% [markdown]
# The previous evaluation has shown that:
# - There are some numerical features, that should be encoded as non-numerical features.
# - Most features are far from normally distributed.Those distributions will have to be shifted.
# - Missing values have to be imputed.
# - There is some multicollinearity in amongst the features in the dataset.
#
# ### Feature Engineering

# %%
## Imputation of missing values
# PoolQC: NA means no pool, therefore None is imputed as its own category.
df['PoolQC'] = df['PoolQC'].fillna('None')

# MiscFeature: NA means, that there is no specific additional feature. Therefore None is imputed as its own category.
df['MiscFeature'] = df['MiscFeature'].fillna('None')

# Alley: NA means no alley access
df['Alley'] = df['Alley'].fillna('None')

# Fence: NA means no fence
df['Fence'] = df['Fence'].fillna('None')

# FireplaceQu: NA means no fireplace
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')

# GarageType: NA means no garage (garage features are treated accordingly)
df['GarageType'] = df['GarageType'].fillna('None')
df['GarageCond'] = df['GarageCond'].fillna('None')
df['GarageFinish'] = df['GarageFinish'].fillna('None')
df['GarageQual'] = df['GarageQual'].fillna('None')
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# BsmtFinType2: NA means no basement (related features are treated accordingly)
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('None')
df['BsmtExposure'] = df['BsmtExposure'].fillna('None')
df['BsmtQual'] = df['BsmtQual'].fillna('None')
df['BsmtCond'] = df['BsmtCond'].fillna('None')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('None')

# MasVnrArea: Object can have no veneer area
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# MasVnrType: See above
df['MasVnrType'] = df['MasVnrType'].fillna('None')

# Electrical: As the most frequent value by far is SBrkr, and only one single value is affected, SBkrkr can be imputed.
df['Electrical'] = df['Electrical'].fillna('SBrkr')

# MSZoning: Assign Mode of data set to missing values
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])
assert df['MSZoning'].isnull().sum()==0

# Utilities: The overwhelming majority of train observations are 'AllPub', therefore, that value is imputed
df['Utilities'] = df['Utilities'].fillna('AllPub')

# Functional: Similar to utilities but less pronounced → under the assumption, that there is no systematic reason for a certain value to
# be missing, the mode is the best option again
df['Functional'] = df['Functional'].fillna(df['Functional'].mode()[0])

# Exterior2nd: See 'Functional'
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])

# SaleType: See 'Functional'
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

# Exterior1st: See 'Functional'
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])

# KitchenQual: See 'Functional'
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])

# GarageCars: Similar to other Garage related features
df['GarageCars'] = df['GarageCars'].fillna(0)

# GarageArea: Similar to other Garage related features
df['GarageArea'] = df['GarageArea'].fillna(0)

# Bsmt Features: Similar consideration as in Training set (np.nan = no Basement so np.nan → None)
df['TotalBsmtSF'] = df['TotalBsmtSF'].fillna(0)
df['BsmtFinSF1'] = df['BsmtFinSF1'].fillna(0)
df['BsmtFinSF2'] = df['BsmtFinSF2'].fillna(0)
df['BsmtUnfSF'] = df['BsmtUnfSF'].fillna(0)
df['BsmtHalfBath'] = df['BsmtHalfBath'].fillna(0)
df['BsmtFullBath'] = df['BsmtFullBath'].fillna(0)

# LotFrontage: Missing values must be imputed; as there is no other obvious way, the value can be imputed by linear regression
tsvd = TruncatedSVD(n_components=10)
imputation_pipeline = Pipeline([('encoder',OneHotEncoder(handle_unknown='ignore')),
                               ('tsvd',tsvd),
                               ('linreg',LinearRegression())])

X_imp_train = df.loc[df['LotFrontage'].notnull()].drop(['SalePrice','LotFrontage'],axis=1)
y_imp_train = df.loc[:,'LotFrontage'].dropna()
X_imp = df.loc[df['LotFrontage'].isnull()].drop(['SalePrice','LotFrontage'],axis=1)

imputation_pipeline.fit(X_imp_train,y_imp_train)
imp_values = imputation_pipeline.predict(X_imp)

index_list = df.loc[df['LotFrontage'].isnull()].index.tolist()
imp_Series = pd.Series(imp_values,index=index_list)
df['LotFrontage'] = df['LotFrontage'].fillna(imp_Series)

assert df.drop('SalePrice',axis=1).isnull().sum().sum() == 0

# %%
#Add information: Houses with same YearRemodAdd and YearBuilt have no Remod Added

df.loc[df['YearRemodAdd']==df['YearBuilt'],'YearRemodAdd'] = 'None'

# %%
# Converting numerical features to objects: Nominal features
to_be_converted = ['MoSold','YrSold','YearBuilt','YearRemodAdd','GarageYrBlt','MSSubClass']

for feature in to_be_converted:
    df[feature].astype(object)

# %%
# Convert numerical features to objects/categories: Ordinal Features
to_be_converted_ordinal = ['MSZoning','Alley','MasVnrType','ExterQual','FireplaceQu','BsmtQual','BsmtCond','HeatingQC','KitchenQual',
                           'GarageQual','GarageCond','PoolQC','Utilities','BldgType','OverallQual','OverallCond','ExterCond','BsmtExposure',
                           'BsmtFinType1','BsmtFinType2','Functional','GarageFinish','PavedDrive','Fence']

for feature in to_be_converted_ordinal:
    le = LabelEncoder()
    encoded_feature = le.fit_transform(df[feature])
    df[feature] = encoded_feature

# %%
# Shift numerical features' distribution towards normal distribution by running a boxcox transformation over all remaining numerical features
# For easier interpretability, use simple log transformation for target variable 

num_features = [feature for feature in df.columns if df[feature].dtype != 'object']
for feature in num_features:
    if feature != 'SalePrice':
        transform_data = df[feature].loc[df[feature]>0]
        lm = 0.15
        transform_result = stats.boxcox(transform_data,lm)
        transform_impose = np.empty_like(df[feature])
        transform_impose[df[feature] > 0] = transform_result
        transform_impose[df[feature]<= 0] = df[feature].loc[df[feature]<=0]
        df[feature] = transform_impose
    else:
        df[feature] = df[feature].transform(lambda x: np.log(x))

# %%
# Get dummies from dataset
df_processed = pd.get_dummies(df)

# %%
# Data Wrangling is concluded
train_processed = df_processed.loc[df_processed['SalePrice'].notnull()]
test_processed = df_processed.loc[df_processed['SalePrice'].isnull()]
assert train_processed.isnull().sum().sum() == 0
assert test_processed.isnull().sum().sum() == test_processed.shape[0]
assert train_processed.shape[1] == test_processed.shape[1]
assert test_processed.shape[0] == df_test.shape[0]
train_processed.to_csv('train_processed.csv',index_label='Id')
test_processed.drop('SalePrice',axis=1).to_csv('test_processed.csv',index_label='Id')

# %% [markdown]
# ## Basic Models

# %%
# Load processed training data
train_data = pd.read_csv('train_processed.csv',index_col='Id')

# %%
# Prepare the data
X = train_data.drop('SalePrice',axis=1)
y_train = np.array(train_data.loc[:,'SalePrice'])

# %%
# Data preparation
preparation_pipeline = make_pipeline(StandardScaler())
print(X.shape)
X_train = preparation_pipeline.fit_transform(X)
# Out:
# (1460, 273)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Prepare KFold validation function
def rmsle_cv(model):
    kf = KFold(3,shuffle=True,random_state=42).get_n_splits(X_train)
    rmse = np.sqrt(-cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=kf))
    return rmse

# %%
# Define model test function
# TODO: Implement GridSearchCV or RandomizedGridSearchCV
def model_testing(model):
    rmsle_train_score = rmsle_cv(model)
    model.fit(X_train,y_train)
    
    return rmsle_train_score

# %%
# Train Base Models
lin_reg = LinearRegression()
rand_for = RandomForestRegressor()
sup_vec_reg = SVR()
ada_boost = AdaBoostRegressor()
grad_boost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                       max_depth=4, max_features='sqrt',
                                       min_samples_leaf=15, min_samples_split=10, 
                                       loss='huber', random_state =5)
xgboost_reg = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                               learning_rate=0.05, max_depth=3, 
                               min_child_weight=1.7817, n_estimators=2200,
                               reg_alpha=0.4640, reg_lambda=0.8571,
                               subsample=0.5213, silent=1,
                               random_state =7, nthread = -1)

models= [lin_reg,rand_for,sup_vec_reg,ada_boost,grad_boost,xgboost_reg]
names = ['LR','RF','SVR','ABR','GBR','XGB-Test']

train_results = list(map(model_testing,models))
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# Training Results
rmsle_train_scores = [train_results[i] for i in range(len(train_results))]

# %%
# Plotting Training Results
train_results_df = pd.DataFrame(rmsle_train_scores,columns=['CV'+str(i+1) for i in range(rmsle_train_scores[0].shape[0])])
train_results_df['Model'] = names
train_results_df1 = train_results_df.melt(id_vars='Model',var_name='Validation',value_name='RMSLE-Score')
sns.barplot(x='Model',y='RMSLE-Score',data=train_results_df1,hue='Validation').set_title('Training RMSLEs')
plt.ylim(0,0.5)

plt.show()
print(train_results_df)
# Out:
#         CV1       CV2       CV3     Model
# 0  2.888806  4.854861  4.913324        LR
# 1  0.181793  0.201859  0.173893        RF
# 2  0.214188  0.224588  0.195345       SVR
# 3  0.195426  0.213019  0.177075       ABR
# 4  0.194706  0.209341  0.187016       GBR
# 5  0.154391  0.173051  0.146844  XGB-Test

# %%
# Train a UL model on the data (for testing purposes of the meta model)
# Model: Gaussian Mixture Model, testing for optimal k
from sklearn.mixture import GaussianMixture

# %%
# Define Testing function
def gmm_test(data,max_components):
    total_score = []
    test_components = []
    for i in range(max_components):
        model = GaussianMixture(n_components=i+1)
        labels = model.fit_predict(data)
        score = model.aic(data)
        total_score.append(score)
        test_components.append(i+1)
    sns.lineplot(x=test_components,y=total_score)
    plt.xticks(list(range(1,31)))
    plt.show()

# %%
# Testing for the optimal model
gmm_test(X_train,30)

# %%
# It appears, that the optimal model, according to the AIC, is one with n_components = 22
gm_model = GaussianMixture(n_components = 22)
label_predictions = gm_model.fit_predict(X_train)
if gm_model not in models:
    models.append(gm_model)

# %%
# Combine predictions and labels
lin_reg_pred = lin_reg.predict(X_train)
rand_for_pred = rand_for.predict(X_train)
sup_vec_reg_pred = sup_vec_reg.predict(X_train)
ada_boost_pred = ada_boost.predict(X_train)
grad_boost_pred = grad_boost.predict(X_train)
xgboost_reg_pred = xgboost_reg.predict(X_train)

meta_data_train = np.column_stack((lin_reg_pred,rand_for_pred,sup_vec_reg_pred,ada_boost_pred,grad_boost_pred,xgboost_reg_pred,label_predictions))

# %%
# Train Meta model (keras DLN)
from keras.models import Sequential
from keras.layers import Dropout, Dense, LeakyReLU

meta_model_dnn = Sequential()
meta_model_dnn.add(Dense(256,kernel_initializer='normal',input_dim=meta_data_train.shape[1]))
meta_model_dnn.add(Dropout(rate=0.2))
meta_model_dnn.add(LeakyReLU())

for i in range(100):
    meta_model_dnn.add(Dense(128,kernel_initializer='normal'))
    meta_model_dnn.add(Dropout(rate=0.2))
    meta_model_dnn.add(LeakyReLU())

meta_model_dnn.add(Dense(1,kernel_initializer='normal',activation='linear'))

meta_model_dnn.compile(optimizer='SGD',loss='mean_squared_error',metrics=['mean_squared_error'])

meta_model_dnn.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_66 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_67 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_72 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_73 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_74 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_76 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_77 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_81 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_82 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_86 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_88 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_91 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_92 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_93 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_93 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_94 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_95 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_96 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_97 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_98 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_99 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_100 (LeakyReLU)  (None, 128)               0
# _________________________________________________________________
# dense_101 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_101 (LeakyReLU)  (None, 128)               0
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 1,669,761
# Trainable params: 1,669,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train Meta Model
meta_model_dnn.fit(meta_data_train,y_train,epochs=500,batch_size=32,shuffle=True,validation_split=0.1,verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1314 samples, validate on 146 samples
# Epoch 1/500
# 1314/1314 [==============================] - 14s 11ms/step - loss: 28.8884 - mean_squared_error: 28.8884 - val_loss: 0.5513 - val_mean_squared_error: 0.5513
# Epoch 2/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 1.1508 - mean_squared_error: 1.1508 - val_loss: 1.1013 - val_mean_squared_error: 1.1013
# Epoch 3/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 1.0402 - mean_squared_error: 1.0402 - val_loss: 0.6475 - val_mean_squared_error: 0.6475
# Epoch 4/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.9989 - mean_squared_error: 0.9989 - val_loss: 0.1872 - val_mean_squared_error: 0.1872
# Epoch 5/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8516 - mean_squared_error: 0.8516 - val_loss: 0.3797 - val_mean_squared_error: 0.3797
# Epoch 6/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8239 - mean_squared_error: 0.8239 - val_loss: 1.6899 - val_mean_squared_error: 1.6899
# Epoch 7/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 1.7013 - val_mean_squared_error: 1.7013
# Epoch 8/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8104 - mean_squared_error: 0.8104 - val_loss: 0.6413 - val_mean_squared_error: 0.6413
# Epoch 9/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6933 - mean_squared_error: 0.6933 - val_loss: 0.6375 - val_mean_squared_error: 0.6375
# Epoch 10/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.7310 - mean_squared_error: 0.7310 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 11/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6476 - mean_squared_error: 0.6476 - val_loss: 0.1732 - val_mean_squared_error: 0.1732
# Epoch 12/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6654 - mean_squared_error: 0.6654 - val_loss: 0.1832 - val_mean_squared_error: 0.1832
# Epoch 13/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6480 - mean_squared_error: 0.6480 - val_loss: 0.2164 - val_mean_squared_error: 0.2164
# Epoch 14/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5886 - mean_squared_error: 0.5886 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 15/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5987 - mean_squared_error: 0.5987 - val_loss: 0.1879 - val_mean_squared_error: 0.1879
# Epoch 16/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5795 - mean_squared_error: 0.5795 - val_loss: 0.2362 - val_mean_squared_error: 0.2362
# Epoch 17/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6033 - mean_squared_error: 0.6033 - val_loss: 0.2389 - val_mean_squared_error: 0.2389
# Epoch 18/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5773 - mean_squared_error: 0.5773 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 19/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.5371 - mean_squared_error: 0.5371 - val_loss: 0.2464 - val_mean_squared_error: 0.2464
# Epoch 20/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5459 - mean_squared_error: 0.5459 - val_loss: 0.1876 - val_mean_squared_error: 0.1876
# Epoch 21/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5379 - mean_squared_error: 0.5379 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 22/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5205 - mean_squared_error: 0.5205 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 23/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5181 - mean_squared_error: 0.5181 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 24/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5289 - mean_squared_error: 0.5289 - val_loss: 0.2666 - val_mean_squared_error: 0.2666
# Epoch 25/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5010 - mean_squared_error: 0.5010 - val_loss: 0.2668 - val_mean_squared_error: 0.2668
# Epoch 26/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5040 - mean_squared_error: 0.5040 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 27/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5062 - mean_squared_error: 0.5062 - val_loss: 0.1906 - val_mean_squared_error: 0.1906
# Epoch 28/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4861 - mean_squared_error: 0.4861 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 29/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4794 - mean_squared_error: 0.4794 - val_loss: 0.1778 - val_mean_squared_error: 0.1778
# Epoch 30/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4661 - mean_squared_error: 0.4661 - val_loss: 0.1794 - val_mean_squared_error: 0.1794
# Epoch 31/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4361 - mean_squared_error: 0.4361 - val_loss: 0.2309 - val_mean_squared_error: 0.2309
# Epoch 32/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4674 - mean_squared_error: 0.4674 - val_loss: 0.1865 - val_mean_squared_error: 0.1865
# Epoch 33/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4947 - mean_squared_error: 0.4947 - val_loss: 0.1990 - val_mean_squared_error: 0.1990
# Epoch 34/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4174 - mean_squared_error: 0.4174 - val_loss: 0.1689 - val_mean_squared_error: 0.1689
# Epoch 35/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4369 - mean_squared_error: 0.4369 - val_loss: 0.1967 - val_mean_squared_error: 0.1967
# Epoch 36/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4647 - mean_squared_error: 0.4647 - val_loss: 0.2083 - val_mean_squared_error: 0.2083
# Epoch 37/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4343 - mean_squared_error: 0.4343 - val_loss: 0.1721 - val_mean_squared_error: 0.1721
# Epoch 38/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4629 - mean_squared_error: 0.4629 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 39/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4666 - mean_squared_error: 0.4666 - val_loss: 0.2474 - val_mean_squared_error: 0.2474
# Epoch 40/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4434 - mean_squared_error: 0.4434 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 41/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4389 - mean_squared_error: 0.4389 - val_loss: 0.2444 - val_mean_squared_error: 0.2444
# Epoch 42/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4120 - mean_squared_error: 0.4120 - val_loss: 0.2823 - val_mean_squared_error: 0.2823
# Epoch 43/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4299 - mean_squared_error: 0.4299 - val_loss: 0.1778 - val_mean_squared_error: 0.1778
# Epoch 44/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4165 - mean_squared_error: 0.4165 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 45/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3982 - mean_squared_error: 0.3982 - val_loss: 0.4974 - val_mean_squared_error: 0.4974
# Epoch 46/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3966 - mean_squared_error: 0.3966 - val_loss: 0.3837 - val_mean_squared_error: 0.3837
# Epoch 47/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4142 - mean_squared_error: 0.4142 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 48/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3914 - mean_squared_error: 0.3914 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 49/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3873 - mean_squared_error: 0.3873 - val_loss: 0.1749 - val_mean_squared_error: 0.1749
# Epoch 50/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3562 - mean_squared_error: 0.3562 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Epoch 51/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3970 - mean_squared_error: 0.3970 - val_loss: 0.1696 - val_mean_squared_error: 0.1696
# Epoch 52/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3816 - mean_squared_error: 0.3816 - val_loss: 0.2463 - val_mean_squared_error: 0.2463
# Epoch 53/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3952 - mean_squared_error: 0.3952 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 54/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3675 - mean_squared_error: 0.3675 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 55/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3872 - mean_squared_error: 0.3872 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 56/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3829 - mean_squared_error: 0.3829 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 57/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3628 - mean_squared_error: 0.3628 - val_loss: 0.2026 - val_mean_squared_error: 0.2026
# Epoch 58/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3683 - mean_squared_error: 0.3683 - val_loss: 0.1756 - val_mean_squared_error: 0.1756
# Epoch 59/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3707 - mean_squared_error: 0.3707 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 60/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3383 - mean_squared_error: 0.3383 - val_loss: 0.2553 - val_mean_squared_error: 0.2553
# Epoch 61/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3839 - mean_squared_error: 0.3839 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 62/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3479 - mean_squared_error: 0.3479 - val_loss: 0.2003 - val_mean_squared_error: 0.2003
# Epoch 63/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3703 - mean_squared_error: 0.3703 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 64/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3626 - mean_squared_error: 0.3626 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 65/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3544 - mean_squared_error: 0.3544 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 66/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3358 - mean_squared_error: 0.3358 - val_loss: 0.1812 - val_mean_squared_error: 0.1812
# Epoch 67/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3336 - mean_squared_error: 0.3336 - val_loss: 0.2046 - val_mean_squared_error: 0.2046
# Epoch 68/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3549 - mean_squared_error: 0.3549 - val_loss: 0.2001 - val_mean_squared_error: 0.2001
# Epoch 69/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3442 - mean_squared_error: 0.3442 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 70/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3628 - mean_squared_error: 0.3628 - val_loss: 0.2456 - val_mean_squared_error: 0.2456
# Epoch 71/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3541 - mean_squared_error: 0.3541 - val_loss: 0.1940 - val_mean_squared_error: 0.1940
# Epoch 72/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3345 - mean_squared_error: 0.3345 - val_loss: 0.1737 - val_mean_squared_error: 0.1737
# Epoch 73/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3209 - mean_squared_error: 0.3209 - val_loss: 0.1728 - val_mean_squared_error: 0.1728
# Epoch 74/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3370 - mean_squared_error: 0.3370 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 75/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3480 - mean_squared_error: 0.3480 - val_loss: 0.2123 - val_mean_squared_error: 0.2123
# Epoch 76/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3205 - mean_squared_error: 0.3205 - val_loss: 0.2670 - val_mean_squared_error: 0.2670
# Epoch 77/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3439 - mean_squared_error: 0.3439 - val_loss: 0.2021 - val_mean_squared_error: 0.2021
# Epoch 78/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3251 - mean_squared_error: 0.3251 - val_loss: 0.4067 - val_mean_squared_error: 0.4067
# Epoch 79/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3400 - mean_squared_error: 0.3400 - val_loss: 0.1742 - val_mean_squared_error: 0.1742
# Epoch 80/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3213 - mean_squared_error: 0.3213 - val_loss: 0.1760 - val_mean_squared_error: 0.1760
# Epoch 81/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3175 - mean_squared_error: 0.3175 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 82/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3321 - mean_squared_error: 0.3321 - val_loss: 0.1692 - val_mean_squared_error: 0.1692
# Epoch 83/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3309 - mean_squared_error: 0.3309 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 84/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3202 - mean_squared_error: 0.3202 - val_loss: 0.1872 - val_mean_squared_error: 0.1872
# Epoch 85/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3289 - mean_squared_error: 0.3289 - val_loss: 0.2413 - val_mean_squared_error: 0.2413
# Epoch 86/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3211 - mean_squared_error: 0.3211 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 87/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3188 - mean_squared_error: 0.3188 - val_loss: 0.1743 - val_mean_squared_error: 0.1743
# Epoch 88/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3103 - mean_squared_error: 0.3103 - val_loss: 0.1675 - val_mean_squared_error: 0.1675
# Epoch 89/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3282 - mean_squared_error: 0.3282 - val_loss: 0.1671 - val_mean_squared_error: 0.1671
# Epoch 90/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3013 - mean_squared_error: 0.3013 - val_loss: 0.3504 - val_mean_squared_error: 0.3504
# Epoch 91/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3066 - mean_squared_error: 0.3066 - val_loss: 0.1951 - val_mean_squared_error: 0.1951
# Epoch 92/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3098 - mean_squared_error: 0.3098 - val_loss: 0.1940 - val_mean_squared_error: 0.1940
# Epoch 93/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2918 - mean_squared_error: 0.2918 - val_loss: 0.1735 - val_mean_squared_error: 0.1735
# Epoch 94/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2901 - mean_squared_error: 0.2901 - val_loss: 0.1729 - val_mean_squared_error: 0.1729
# Epoch 95/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3059 - mean_squared_error: 0.3059 - val_loss: 0.1778 - val_mean_squared_error: 0.1778
# Epoch 96/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2895 - mean_squared_error: 0.2895 - val_loss: 0.3012 - val_mean_squared_error: 0.3012
# Epoch 97/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3102 - mean_squared_error: 0.3102 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 98/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3104 - mean_squared_error: 0.3104 - val_loss: 0.2301 - val_mean_squared_error: 0.2301
# Epoch 99/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2916 - mean_squared_error: 0.2916 - val_loss: 0.2464 - val_mean_squared_error: 0.2464
# Epoch 100/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3110 - mean_squared_error: 0.3110 - val_loss: 0.1633 - val_mean_squared_error: 0.1633
# Epoch 101/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2932 - mean_squared_error: 0.2932 - val_loss: 0.1673 - val_mean_squared_error: 0.1673
# Epoch 102/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2961 - mean_squared_error: 0.2961 - val_loss: 0.1750 - val_mean_squared_error: 0.1750
# Epoch 103/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2975 - mean_squared_error: 0.2975 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 104/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2841 - mean_squared_error: 0.2841 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 105/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2890 - mean_squared_error: 0.2890 - val_loss: 0.2017 - val_mean_squared_error: 0.2017
# Epoch 106/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3050 - mean_squared_error: 0.3050 - val_loss: 0.1695 - val_mean_squared_error: 0.1695
# Epoch 107/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2911 - mean_squared_error: 0.2911 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 108/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2775 - mean_squared_error: 0.2775 - val_loss: 0.2590 - val_mean_squared_error: 0.2590
# Epoch 109/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2871 - mean_squared_error: 0.2871 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 110/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2923 - mean_squared_error: 0.2923 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 111/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2778 - mean_squared_error: 0.2778 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 112/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2735 - mean_squared_error: 0.2735 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 113/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2757 - mean_squared_error: 0.2757 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 114/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2937 - mean_squared_error: 0.2937 - val_loss: 0.1781 - val_mean_squared_error: 0.1781
# Epoch 115/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2883 - mean_squared_error: 0.2883 - val_loss: 0.2269 - val_mean_squared_error: 0.2269
# Epoch 116/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2693 - mean_squared_error: 0.2693 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 117/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2728 - mean_squared_error: 0.2728 - val_loss: 0.1806 - val_mean_squared_error: 0.1806
# Epoch 118/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2655 - mean_squared_error: 0.2655 - val_loss: 0.1678 - val_mean_squared_error: 0.1678
# Epoch 119/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2541 - mean_squared_error: 0.2541 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 120/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2817 - mean_squared_error: 0.2817 - val_loss: 0.1899 - val_mean_squared_error: 0.1899
# Epoch 121/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2732 - mean_squared_error: 0.2732 - val_loss: 0.2742 - val_mean_squared_error: 0.2742
# Epoch 122/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2647 - mean_squared_error: 0.2647 - val_loss: 0.1649 - val_mean_squared_error: 0.1649
# Epoch 123/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2603 - mean_squared_error: 0.2603 - val_loss: 0.1640 - val_mean_squared_error: 0.1640
# Epoch 124/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2758 - mean_squared_error: 0.2758 - val_loss: 0.1682 - val_mean_squared_error: 0.1682
# Epoch 125/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2686 - mean_squared_error: 0.2686 - val_loss: 0.1649 - val_mean_squared_error: 0.1649
# Epoch 126/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2683 - mean_squared_error: 0.2683 - val_loss: 0.1688 - val_mean_squared_error: 0.1688
# Epoch 127/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2734 - mean_squared_error: 0.2734 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 128/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2643 - mean_squared_error: 0.2643 - val_loss: 0.1926 - val_mean_squared_error: 0.1926
# Epoch 129/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2607 - mean_squared_error: 0.2607 - val_loss: 0.1998 - val_mean_squared_error: 0.1998
# Epoch 130/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2673 - mean_squared_error: 0.2673 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 131/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2635 - mean_squared_error: 0.2635 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
# Epoch 132/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2564 - mean_squared_error: 0.2564 - val_loss: 0.1700 - val_mean_squared_error: 0.1700
# Epoch 133/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2598 - mean_squared_error: 0.2598 - val_loss: 0.1715 - val_mean_squared_error: 0.1715
# Epoch 134/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2700 - mean_squared_error: 0.2700 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 135/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2619 - mean_squared_error: 0.2619 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 136/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2556 - mean_squared_error: 0.2556 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 137/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2510 - mean_squared_error: 0.2510 - val_loss: 0.1669 - val_mean_squared_error: 0.1669
# Epoch 138/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2599 - mean_squared_error: 0.2599 - val_loss: 0.2231 - val_mean_squared_error: 0.2231
# Epoch 139/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2685 - mean_squared_error: 0.2685 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 140/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2571 - mean_squared_error: 0.2571 - val_loss: 0.1774 - val_mean_squared_error: 0.1774
# Epoch 141/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2538 - mean_squared_error: 0.2538 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 142/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2622 - mean_squared_error: 0.2622 - val_loss: 0.1901 - val_mean_squared_error: 0.1901
# Epoch 143/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2548 - mean_squared_error: 0.2548 - val_loss: 0.2511 - val_mean_squared_error: 0.2511
# Epoch 144/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2582 - mean_squared_error: 0.2582 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 145/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2561 - mean_squared_error: 0.2561 - val_loss: 0.3212 - val_mean_squared_error: 0.3212
# Epoch 146/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2604 - mean_squared_error: 0.2604 - val_loss: 0.1665 - val_mean_squared_error: 0.1665
# Epoch 147/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2439 - mean_squared_error: 0.2439 - val_loss: 0.1860 - val_mean_squared_error: 0.1860
# Epoch 148/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2499 - mean_squared_error: 0.2499 - val_loss: 0.1878 - val_mean_squared_error: 0.1878
# Epoch 149/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2540 - mean_squared_error: 0.2540 - val_loss: 0.1905 - val_mean_squared_error: 0.1905
# Epoch 150/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.1774 - val_mean_squared_error: 0.1774
# Epoch 151/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2519 - mean_squared_error: 0.2519 - val_loss: 0.1765 - val_mean_squared_error: 0.1765
# Epoch 152/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2491 - mean_squared_error: 0.2491 - val_loss: 0.1773 - val_mean_squared_error: 0.1773
# Epoch 153/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2521 - mean_squared_error: 0.2521 - val_loss: 0.1651 - val_mean_squared_error: 0.1651
# Epoch 154/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2607 - mean_squared_error: 0.2607 - val_loss: 0.1690 - val_mean_squared_error: 0.1690
# Epoch 155/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2522 - mean_squared_error: 0.2522 - val_loss: 0.1785 - val_mean_squared_error: 0.1785
# Epoch 156/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2587 - mean_squared_error: 0.2587 - val_loss: 0.1792 - val_mean_squared_error: 0.1792
# Epoch 157/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2365 - mean_squared_error: 0.2365 - val_loss: 0.1814 - val_mean_squared_error: 0.1814
# Epoch 158/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.1783 - val_mean_squared_error: 0.1783
# Epoch 159/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2527 - mean_squared_error: 0.2527 - val_loss: 0.1894 - val_mean_squared_error: 0.1894
# Epoch 160/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2474 - mean_squared_error: 0.2474 - val_loss: 0.1735 - val_mean_squared_error: 0.1735
# Epoch 161/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2411 - mean_squared_error: 0.2411 - val_loss: 0.1991 - val_mean_squared_error: 0.1991
# Epoch 162/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2425 - mean_squared_error: 0.2425 - val_loss: 0.1657 - val_mean_squared_error: 0.1657
# Epoch 163/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2297 - mean_squared_error: 0.2297 - val_loss: 0.1633 - val_mean_squared_error: 0.1633
# Epoch 164/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2520 - mean_squared_error: 0.2520 - val_loss: 0.1650 - val_mean_squared_error: 0.1650
# Epoch 165/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2319 - mean_squared_error: 0.2319 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 166/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2410 - mean_squared_error: 0.2410 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 167/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 168/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.1904 - val_mean_squared_error: 0.1904
# Epoch 169/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2331 - mean_squared_error: 0.2331 - val_loss: 0.1633 - val_mean_squared_error: 0.1633
# Epoch 170/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2401 - mean_squared_error: 0.2401 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 171/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2390 - mean_squared_error: 0.2390 - val_loss: 0.1621 - val_mean_squared_error: 0.1621
# Epoch 172/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2454 - mean_squared_error: 0.2454 - val_loss: 0.1712 - val_mean_squared_error: 0.1712
# Epoch 173/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2446 - mean_squared_error: 0.2446 - val_loss: 0.1651 - val_mean_squared_error: 0.1651
# Epoch 174/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2187 - mean_squared_error: 0.2187 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 175/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2319 - mean_squared_error: 0.2319 - val_loss: 0.1932 - val_mean_squared_error: 0.1932
# Epoch 176/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2414 - mean_squared_error: 0.2414 - val_loss: 0.1783 - val_mean_squared_error: 0.1783
# Epoch 177/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2365 - mean_squared_error: 0.2365 - val_loss: 0.1688 - val_mean_squared_error: 0.1688
# Epoch 178/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2346 - mean_squared_error: 0.2346 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 179/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2320 - mean_squared_error: 0.2320 - val_loss: 0.2662 - val_mean_squared_error: 0.2662
# Epoch 180/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2348 - mean_squared_error: 0.2348 - val_loss: 0.1677 - val_mean_squared_error: 0.1677
# Epoch 181/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.1633 - val_mean_squared_error: 0.1633
# Epoch 182/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2324 - mean_squared_error: 0.2324 - val_loss: 0.1839 - val_mean_squared_error: 0.1839
# Epoch 183/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2313 - mean_squared_error: 0.2313 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 184/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2441 - mean_squared_error: 0.2441 - val_loss: 0.1767 - val_mean_squared_error: 0.1767
# Epoch 185/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2195 - mean_squared_error: 0.2195 - val_loss: 0.1849 - val_mean_squared_error: 0.1849
# Epoch 186/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2345 - mean_squared_error: 0.2345 - val_loss: 0.2358 - val_mean_squared_error: 0.2358
# Epoch 187/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2391 - mean_squared_error: 0.2391 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 188/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2269 - mean_squared_error: 0.2269 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 189/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2285 - mean_squared_error: 0.2285 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 190/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2298 - mean_squared_error: 0.2298 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 191/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 0.2160 - val_mean_squared_error: 0.2160
# Epoch 192/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2324 - mean_squared_error: 0.2324 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 193/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2193 - mean_squared_error: 0.2193 - val_loss: 0.1621 - val_mean_squared_error: 0.1621
# Epoch 194/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2109 - mean_squared_error: 0.2109 - val_loss: 0.1744 - val_mean_squared_error: 0.1744
# Epoch 195/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2233 - mean_squared_error: 0.2233 - val_loss: 0.1764 - val_mean_squared_error: 0.1764
# Epoch 196/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2244 - mean_squared_error: 0.2244 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 197/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 198/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2293 - mean_squared_error: 0.2293 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 199/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2311 - mean_squared_error: 0.2311 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 200/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2335 - mean_squared_error: 0.2335 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 201/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2284 - mean_squared_error: 0.2284 - val_loss: 0.1976 - val_mean_squared_error: 0.1976
# Epoch 202/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2335 - mean_squared_error: 0.2335 - val_loss: 0.2153 - val_mean_squared_error: 0.2153
# Epoch 203/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2317 - mean_squared_error: 0.2317 - val_loss: 0.1797 - val_mean_squared_error: 0.1797
# Epoch 204/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 205/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.1718 - val_mean_squared_error: 0.1718
# Epoch 206/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - val_loss: 0.1670 - val_mean_squared_error: 0.1670
# Epoch 207/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.1646 - val_mean_squared_error: 0.1646
# Epoch 208/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 209/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2230 - mean_squared_error: 0.2230 - val_loss: 0.1882 - val_mean_squared_error: 0.1882
# Epoch 210/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2218 - mean_squared_error: 0.2218 - val_loss: 0.2362 - val_mean_squared_error: 0.2362
# Epoch 211/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - val_loss: 0.1799 - val_mean_squared_error: 0.1799
# Epoch 212/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2170 - mean_squared_error: 0.2170 - val_loss: 0.1755 - val_mean_squared_error: 0.1755
# Epoch 213/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2239 - mean_squared_error: 0.2239 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 214/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2275 - mean_squared_error: 0.2275 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 215/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2244 - mean_squared_error: 0.2244 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 216/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2155 - mean_squared_error: 0.2155 - val_loss: 0.2000 - val_mean_squared_error: 0.2000
# Epoch 217/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2217 - mean_squared_error: 0.2217 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 218/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2183 - mean_squared_error: 0.2183 - val_loss: 0.2239 - val_mean_squared_error: 0.2239
# Epoch 219/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2191 - mean_squared_error: 0.2191 - val_loss: 0.1689 - val_mean_squared_error: 0.1689
# Epoch 220/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2105 - mean_squared_error: 0.2105 - val_loss: 0.1671 - val_mean_squared_error: 0.1671
# Epoch 221/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2242 - mean_squared_error: 0.2242 - val_loss: 0.1837 - val_mean_squared_error: 0.1837
# Epoch 222/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.1938 - val_mean_squared_error: 0.1938
# Epoch 223/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2194 - mean_squared_error: 0.2194 - val_loss: 0.1669 - val_mean_squared_error: 0.1669
# Epoch 224/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2158 - mean_squared_error: 0.2158 - val_loss: 0.1878 - val_mean_squared_error: 0.1878
# Epoch 225/500
# 1314/1314 [==============================] - 1s 1ms/step - loss: 0.2111 - mean_squared_error: 0.2111 - val_loss: 0.2509 - val_mean_squared_error: 0.2509
# Epoch 226/500
# 1314/1314 [==============================] - 1s 1ms/step - loss: 0.2329 - mean_squared_error: 0.2329 - val_loss: 0.1683 - val_mean_squared_error: 0.1683
# Epoch 227/500
# 1314/1314 [==============================] - 1s 1ms/step - loss: 0.2216 - mean_squared_error: 0.2216 - val_loss: 0.1686 - val_mean_squared_error: 0.1686
# Epoch 228/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2185 - mean_squared_error: 0.2185 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 229/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2186 - mean_squared_error: 0.2186 - val_loss: 0.1854 - val_mean_squared_error: 0.1854
# Epoch 230/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2203 - mean_squared_error: 0.2203 - val_loss: 0.1654 - val_mean_squared_error: 0.1654
# Epoch 231/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2127 - mean_squared_error: 0.2127 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 232/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2145 - mean_squared_error: 0.2145 - val_loss: 0.1660 - val_mean_squared_error: 0.1660
# Epoch 233/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2157 - mean_squared_error: 0.2157 - val_loss: 0.1716 - val_mean_squared_error: 0.1716
# Epoch 234/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.1675 - val_mean_squared_error: 0.1675
# Epoch 235/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2097 - mean_squared_error: 0.2097 - val_loss: 0.1641 - val_mean_squared_error: 0.1641
# Epoch 236/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2134 - mean_squared_error: 0.2134 - val_loss: 0.1848 - val_mean_squared_error: 0.1848
# Epoch 237/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2162 - mean_squared_error: 0.2162 - val_loss: 0.1698 - val_mean_squared_error: 0.1698
# Epoch 238/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2151 - mean_squared_error: 0.2151 - val_loss: 0.1640 - val_mean_squared_error: 0.1640
# Epoch 239/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2193 - mean_squared_error: 0.2193 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 240/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2126 - mean_squared_error: 0.2126 - val_loss: 0.1845 - val_mean_squared_error: 0.1845
# Epoch 241/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2091 - mean_squared_error: 0.2091 - val_loss: 0.1639 - val_mean_squared_error: 0.1639
# Epoch 242/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2163 - mean_squared_error: 0.2163 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 243/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2155 - mean_squared_error: 0.2155 - val_loss: 0.2005 - val_mean_squared_error: 0.2005
# Epoch 244/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2190 - mean_squared_error: 0.2190 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 245/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2003 - mean_squared_error: 0.2003 - val_loss: 0.2180 - val_mean_squared_error: 0.2180
# Epoch 246/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2134 - mean_squared_error: 0.2134 - val_loss: 0.1641 - val_mean_squared_error: 0.1641
# Epoch 247/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2040 - mean_squared_error: 0.2040 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 248/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2110 - mean_squared_error: 0.2110 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 249/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2012 - mean_squared_error: 0.2012 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 250/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2163 - mean_squared_error: 0.2163 - val_loss: 0.1746 - val_mean_squared_error: 0.1746
# Epoch 251/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2047 - mean_squared_error: 0.2047 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 252/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2180 - mean_squared_error: 0.2180 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 253/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2188 - mean_squared_error: 0.2188 - val_loss: 0.1771 - val_mean_squared_error: 0.1771
# Epoch 254/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2128 - mean_squared_error: 0.2128 - val_loss: 0.1688 - val_mean_squared_error: 0.1688
# Epoch 255/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2128 - mean_squared_error: 0.2128 - val_loss: 0.1767 - val_mean_squared_error: 0.1767
# Epoch 256/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2028 - mean_squared_error: 0.2028 - val_loss: 0.1734 - val_mean_squared_error: 0.1734
# Epoch 257/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2072 - mean_squared_error: 0.2072 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 258/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2120 - mean_squared_error: 0.2120 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 259/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2119 - mean_squared_error: 0.2119 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 260/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2135 - mean_squared_error: 0.2135 - val_loss: 0.1792 - val_mean_squared_error: 0.1792
# Epoch 261/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2086 - mean_squared_error: 0.2086 - val_loss: 0.1707 - val_mean_squared_error: 0.1707
# Epoch 262/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2106 - mean_squared_error: 0.2106 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 263/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2002 - mean_squared_error: 0.2002 - val_loss: 0.1650 - val_mean_squared_error: 0.1650
# Epoch 264/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2112 - mean_squared_error: 0.2112 - val_loss: 0.1681 - val_mean_squared_error: 0.1681
# Epoch 265/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2183 - val_mean_squared_error: 0.2183
# Epoch 266/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2099 - mean_squared_error: 0.2099 - val_loss: 0.1811 - val_mean_squared_error: 0.1811
# Epoch 267/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2114 - mean_squared_error: 0.2114 - val_loss: 0.1677 - val_mean_squared_error: 0.1677
# Epoch 268/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1961 - mean_squared_error: 0.1961 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 269/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2074 - mean_squared_error: 0.2074 - val_loss: 0.1668 - val_mean_squared_error: 0.1668
# Epoch 270/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2043 - mean_squared_error: 0.2043 - val_loss: 0.1692 - val_mean_squared_error: 0.1692
# Epoch 271/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2159 - mean_squared_error: 0.2159 - val_loss: 0.1707 - val_mean_squared_error: 0.1707
# Epoch 272/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2175 - mean_squared_error: 0.2175 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 273/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2107 - mean_squared_error: 0.2107 - val_loss: 0.1808 - val_mean_squared_error: 0.1808
# Epoch 274/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2151 - mean_squared_error: 0.2151 - val_loss: 0.1921 - val_mean_squared_error: 0.1921
# Epoch 275/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2136 - mean_squared_error: 0.2136 - val_loss: 0.1857 - val_mean_squared_error: 0.1857
# Epoch 276/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2075 - mean_squared_error: 0.2075 - val_loss: 0.2216 - val_mean_squared_error: 0.2216
# Epoch 277/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2045 - mean_squared_error: 0.2045 - val_loss: 0.1648 - val_mean_squared_error: 0.1648
# Epoch 278/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2014 - mean_squared_error: 0.2014 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 279/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2085 - mean_squared_error: 0.2085 - val_loss: 0.1668 - val_mean_squared_error: 0.1668
# Epoch 280/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2129 - mean_squared_error: 0.2129 - val_loss: 0.1716 - val_mean_squared_error: 0.1716
# Epoch 281/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2047 - mean_squared_error: 0.2047 - val_loss: 0.1718 - val_mean_squared_error: 0.1718
# Epoch 282/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2080 - mean_squared_error: 0.2080 - val_loss: 0.1721 - val_mean_squared_error: 0.1721
# Epoch 283/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1981 - mean_squared_error: 0.1981 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 284/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2080 - mean_squared_error: 0.2080 - val_loss: 0.1888 - val_mean_squared_error: 0.1888
# Epoch 285/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2049 - mean_squared_error: 0.2049 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 286/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2036 - mean_squared_error: 0.2036 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# ...
# Epoch 406/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1885 - mean_squared_error: 0.1885 - val_loss: 0.1768 - val_mean_squared_error: 0.1768
# Epoch 407/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_squared_error: 0.1897 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 408/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1825 - mean_squared_error: 0.1825 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 409/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1884 - mean_squared_error: 0.1884 - val_loss: 0.1792 - val_mean_squared_error: 0.1792
# Epoch 410/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1914 - mean_squared_error: 0.1914 - val_loss: 0.1797 - val_mean_squared_error: 0.1797
# Epoch 411/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1960 - mean_squared_error: 0.1960 - val_loss: 0.1724 - val_mean_squared_error: 0.1724
# Epoch 412/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1908 - mean_squared_error: 0.1908 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 413/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1855 - mean_squared_error: 0.1855 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 414/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1874 - mean_squared_error: 0.1874 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 415/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1929 - mean_squared_error: 0.1929 - val_loss: 0.1680 - val_mean_squared_error: 0.1680
# Epoch 416/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1944 - mean_squared_error: 0.1944 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 417/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1850 - mean_squared_error: 0.1850 - val_loss: 0.1679 - val_mean_squared_error: 0.1679
# Epoch 418/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1874 - mean_squared_error: 0.1874 - val_loss: 0.1689 - val_mean_squared_error: 0.1689
# Epoch 419/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1857 - mean_squared_error: 0.1857 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 420/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1944 - mean_squared_error: 0.1944 - val_loss: 0.1724 - val_mean_squared_error: 0.1724
# Epoch 421/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1957 - mean_squared_error: 0.1957 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 422/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1858 - mean_squared_error: 0.1858 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 423/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1843 - mean_squared_error: 0.1843 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 424/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1915 - mean_squared_error: 0.1915 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 425/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1900 - mean_squared_error: 0.1900 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 426/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1833 - mean_squared_error: 0.1833 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 427/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1848 - mean_squared_error: 0.1848 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 428/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1893 - mean_squared_error: 0.1893 - val_loss: 0.1897 - val_mean_squared_error: 0.1897
# Epoch 429/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1857 - mean_squared_error: 0.1857 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 430/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1856 - mean_squared_error: 0.1856 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 431/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 432/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1886 - mean_squared_error: 0.1886 - val_loss: 0.1688 - val_mean_squared_error: 0.1688
# Epoch 433/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1840 - mean_squared_error: 0.1840 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 434/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1853 - mean_squared_error: 0.1853 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 435/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1902 - mean_squared_error: 0.1902 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 436/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1791 - mean_squared_error: 0.1791 - val_loss: 0.1751 - val_mean_squared_error: 0.1751
# Epoch 437/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1857 - mean_squared_error: 0.1857 - val_loss: 0.1790 - val_mean_squared_error: 0.1790
# Epoch 438/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1953 - mean_squared_error: 0.1953 - val_loss: 0.1654 - val_mean_squared_error: 0.1654
# Epoch 439/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1871 - mean_squared_error: 0.1871 - val_loss: 0.1725 - val_mean_squared_error: 0.1725
# Epoch 440/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1850 - mean_squared_error: 0.1850 - val_loss: 0.1697 - val_mean_squared_error: 0.1697
# Epoch 441/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1783 - mean_squared_error: 0.1783 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 442/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1833 - mean_squared_error: 0.1833 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 443/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1831 - mean_squared_error: 0.1831 - val_loss: 0.1832 - val_mean_squared_error: 0.1832
# Epoch 444/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1833 - mean_squared_error: 0.1833 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 445/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1831 - mean_squared_error: 0.1831 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 446/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1832 - mean_squared_error: 0.1832 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 447/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1851 - mean_squared_error: 0.1851 - val_loss: 0.1761 - val_mean_squared_error: 0.1761
# Epoch 448/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1877 - mean_squared_error: 0.1877 - val_loss: 0.1682 - val_mean_squared_error: 0.1682
# Epoch 449/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1850 - mean_squared_error: 0.1850 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 450/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1870 - mean_squared_error: 0.1870 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 451/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1825 - mean_squared_error: 0.1825 - val_loss: 0.1683 - val_mean_squared_error: 0.1683
# Epoch 452/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1916 - mean_squared_error: 0.1916 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
# Epoch 453/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.1640 - val_mean_squared_error: 0.1640
# Epoch 454/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1812 - mean_squared_error: 0.1812 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 455/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1850 - mean_squared_error: 0.1850 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 456/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1788 - mean_squared_error: 0.1788 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 457/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1806 - mean_squared_error: 0.1806 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 458/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 459/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1837 - mean_squared_error: 0.1837 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 460/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1786 - mean_squared_error: 0.1786 - val_loss: 0.1663 - val_mean_squared_error: 0.1663
# Epoch 461/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1860 - mean_squared_error: 0.1860 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 462/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1858 - mean_squared_error: 0.1858 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 463/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 464/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1800 - mean_squared_error: 0.1800 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 465/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1788 - mean_squared_error: 0.1788 - val_loss: 0.1690 - val_mean_squared_error: 0.1690
# Epoch 466/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_squared_error: 0.1896 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 467/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1895 - mean_squared_error: 0.1895 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 468/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 469/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1906 - mean_squared_error: 0.1906 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 470/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1877 - mean_squared_error: 0.1877 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 471/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1869 - mean_squared_error: 0.1869 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 472/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1810 - mean_squared_error: 0.1810 - val_loss: 0.1714 - val_mean_squared_error: 0.1714
# Epoch 473/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.1685 - val_mean_squared_error: 0.1685
# Epoch 474/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1769 - mean_squared_error: 0.1769 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 475/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1797 - mean_squared_error: 0.1797 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 476/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1773 - mean_squared_error: 0.1773 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 477/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.1677 - val_mean_squared_error: 0.1677
# Epoch 478/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1819 - mean_squared_error: 0.1819 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 479/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1847 - mean_squared_error: 0.1847 - val_loss: 0.1669 - val_mean_squared_error: 0.1669
# Epoch 480/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1771 - mean_squared_error: 0.1771 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 481/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1831 - mean_squared_error: 0.1831 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 482/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1835 - mean_squared_error: 0.1835 - val_loss: 0.1650 - val_mean_squared_error: 0.1650
# Epoch 483/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1849 - mean_squared_error: 0.1849 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 484/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1870 - mean_squared_error: 0.1870 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 485/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1855 - mean_squared_error: 0.1855 - val_loss: 0.1654 - val_mean_squared_error: 0.1654
# Epoch 486/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1859 - mean_squared_error: 0.1859 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 487/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1837 - mean_squared_error: 0.1837 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 488/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1829 - mean_squared_error: 0.1829 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 489/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1760 - mean_squared_error: 0.1760 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 490/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1823 - mean_squared_error: 0.1823 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 491/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1825 - mean_squared_error: 0.1825 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 492/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1757 - mean_squared_error: 0.1757 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 493/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1840 - mean_squared_error: 0.1840 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 494/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1810 - mean_squared_error: 0.1810 - val_loss: 0.1677 - val_mean_squared_error: 0.1677
# Epoch 495/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1775 - mean_squared_error: 0.1775 - val_loss: 0.1735 - val_mean_squared_error: 0.1735
# Epoch 496/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1786 - mean_squared_error: 0.1786 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 497/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1715 - mean_squared_error: 0.1715 - val_loss: 0.1648 - val_mean_squared_error: 0.1648
# Epoch 498/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1829 - mean_squared_error: 0.1829 - val_loss: 0.1803 - val_mean_squared_error: 0.1803
# Epoch 499/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1853 - mean_squared_error: 0.1853 - val_loss: 0.1694 - val_mean_squared_error: 0.1694
# Epoch 500/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1783 - mean_squared_error: 0.1783 - val_loss: 0.1673 - val_mean_squared_error: 0.1673

# %%
# Evaluate Meta Model
yhat = meta_model_dnn.predict(meta_data_train)
meta_training_score = rmsle(y_train,yhat,exponential_transformation=True)
print('Meta-Model Training Score: {}'.format(meta_training_score))
# Out:
# Meta-Model Training Score: 0.4021609324486011

# %%
# As the simple Keras model did not perform as hoped, let's use a simple XGBRegressor model
xgb_meta = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                            learning_rate=0.05, max_depth=3, 
                            min_child_weight=1.7817, n_estimators=2200,
                            reg_alpha=0.4640, reg_lambda=0.8571,
                            subsample=0.5213, silent=1,
                            random_state =7, nthread = -1)

xgb_meta.fit(meta_data_train,y_train)
test_prediction = xgb_meta.predict(meta_data_train)

print('XGBR Meta Model Score: {}'.format(rmsle(y_train,test_prediction,exponential_transformation=True)))
# Out:
# XGBR Meta Model Score: 0.037821582113786945

# %% [markdown]
# ### Submission

# %%
# Although the final Meta model returned the best accuracy, let's try and submit the results from all models!
submission_df = pd.read_csv('test_processed.csv',index_col='Id')
submission_index = submission_df.index.to_list()

# %%
# Prepare test_data
submission_pipeline = make_pipeline(StandardScaler())
X_test = submission_pipeline.fit_transform(submission_df)
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Create Base Predictions
def create_submissions(models,meta_model,test_data):
    meta_data = np.empty((test_data.shape[0],len(models)))
    result_dict = {}
    for i,model in enumerate(models):
        yhat = np.exp(model.predict(test_data))
        yhat_meta = model.predict(test_data)
        meta_data[:,i] = yhat_meta
        result_dict[type(model).__name__] = yhat
    else:
        meta_predictions = np.exp(meta_model.predict(meta_data))
        result_dict['MetaModel'] = meta_predictions
    
    for key,value in result_dict.items():
        if key != 'GaussianMixture':
            export = pd.DataFrame(value,columns=['SalePrice'])
            export.index = submission_index
            export.index.name='Id'            
            export.to_csv(key+'.csv')

# %%
# Export Base Predictions
assert X_train.shape[1] == X_test.shape[1] and X_test.shape[0] == df_test.shape[0]

meta_data = create_submissions(models,xgb_meta,X_test)
